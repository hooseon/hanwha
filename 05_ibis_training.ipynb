# %%
# load library

import os, glob
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt

import ibis
import ibis.selectors as s
from ibis.interactive import *

# %%
# options 

ibis.options.interactive = True

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# #### pandas 대비 장점 확인

# %%
# %ls -lh
# Out:
# total 49654376
# -rw-r--r--@ 1 hooseonlee  staff   155K Dec 18 15:35 (기술공통) DATA Engineering_커리큘럼.pdf
# -rwx------@ 1 hooseonlee  staff   199K Dec 23 09:59 00_python_training.ipynb*
# -rw-r--r--@ 1 hooseonlee  staff    41K Jan  1 16:01 01_pandas_training.ipynb
# -rw-r--r--@ 1 hooseonlee  staff   142K Jan  4 15:25 02_pandas_training.ipynb
# -rw-r--r--@ 1 hooseonlee  staff    37K Jan  7 13:29 03_numpy_training.ipynb
# -rw-r--r--@ 1 hooseonlee  staff    16K Jan  7 14:58 04_numpy_training.ipynb
# -rwx------@ 1 hooseonlee  staff   202K Jan 10 18:10 05_ibis_training.ipynb*
# -rwx------@ 1 hooseonlee  staff   498K Dec 21 19:26 06_ibis_training.ipynb*
# -rwx------@ 1 hooseonlee  staff    68K May 10  2023 08_크롤링_인터넷.ipynb*
# -rw-r--r--@ 1 hooseonlee  staff   2.5K Jan  1 15:27 100_my_pandas.py
# -rw-r--r--@ 1 hooseonlee  staff   606B Dec 29 13:40 101_my_ibis.py
# -rw-r--r--@ 1 hooseonlee  staff   1.4K Dec 29 20:35 102_my_ibis.py
# -rwx------@ 1 hooseonlee  staff   234K Jan  6  2024 99_ibis_training_3_big data.ipynb*
# drwxr-xr-x  9 hooseonlee  staff   288B Dec 22 12:23 old/
# -rwx------@ 1 hooseonlee  staff    24G Feb 18  2025 taxi.csv*
# -rwx------@ 1 hooseonlee  staff    46M Dec 22 12:52 강의_Python.key*
# -rw-r--r--@ 1 hooseonlee  staff    15K Jan 10 17:06 연습장.ipynb

# %% [markdown]
# #### pandas는 다운되지만 ibis는 읽습니다.

# %%
taxi = ibis.read_csv("taxi.csv")
taxi.head()
# Out:
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ vendor_name ┃ pickup_datetime     ┃ dropoff_datetime    ┃ passenger_count ┃ trip_distance ┃ pickup_longitude ┃ pickup_latitude ┃ rate_code     ┃ store_and_fwd ┃ dropoff_longitude ┃ dropoff_latitude ┃ payment_type ┃ fare_amount ┃ extra   ┃ mta_tax ┃ tip_amount ┃ tolls_amount ┃ total_amount ┃ improvement_surcharge ┃ month ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ string      │ timestamp(6)        │ timestamp(6)        │ int64           │ float64       │ float64          │ float64         │ string        │ boolean       │ float64           │ float64          │ string       │ float64     │ float64 │ float64 │ float64    │ float64      │ float64      │ float64               │ int64 │
# ├─────────────┼─────────────────────┼─────────────────────┼─────────────────┼───────────────┼──────────────────┼─────────────────┼───────────────┼───────────────┼───────────────────┼──────────────────┼──────────────┼─────────────┼─────────┼─────────┼────────────┼──────────────┼──────────────┼───────────────────────┼───────┤
# │ VTS         │ 2015-01-15 07:02:38 │ 2015-01-15 07:13:56 │               1 │          2.83 │       -73.944839 │       40.779278 │ Standard rate │ False         │        -73.974823 │        40.756130 │ Credit card  │        11.0 │     0.0 │     0.5 │       2.75 │          0.0 │        14.55 │                   0.3 │     1 │
# │ VTS         │ 2015-01-23 18:44:27 │ 2015-01-23 18:56:04 │               1 │          2.94 │       -73.994270 │       40.719673 │ Standard rate │ False         │        -73.971031 │        40.695774 │ Credit card  │        11.5 │     1.0 │     0.5 │       2.00 │          0.0 │        15.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:28 │ 2015-01-30 18:20:41 │               1 │          1.60 │       -73.971313 │       40.745457 │ Standard rate │ False         │        -73.991692 │        40.744473 │ Credit card  │         9.0 │     1.0 │     0.5 │       2.16 │          0.0 │        12.96 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:28 │ 2015-01-30 18:27:42 │               1 │          2.80 │       -73.989471 │       40.741554 │ Standard rate │ False         │        -73.959465 │        40.763058 │ Credit card  │        14.0 │     1.0 │     0.5 │       2.50 │          0.0 │        18.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:29 │ 2015-01-30 18:15:39 │               1 │          1.00 │       -73.973083 │       40.755447 │ Standard rate │ False         │        -73.960030 │        40.762199 │ Cash         │         6.5 │     1.0 │     0.5 │       0.00 │          0.0 │         8.30 │                   0.3 │     1 │
# └─────────────┴─────────────────────┴─────────────────────┴─────────────────┴───────────────┴──────────────────┴─────────────────┴───────────────┴───────────────┴───────────────────┴──────────────────┴──────────────┴─────────────┴─────────┴─────────┴────────────┴──────────────┴──────────────┴───────────────────────┴───────┘

# %%
taxi.count()
taxi.group_by("vendor_name").count()
# Out:
# ┌───────────┐
# │ 139372677 │
# └───────────┘
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ vendor_name ┃ CountStar(ibis_read_csv_ar6mhd7mn5dmtbnpexnrwgw7ui) ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ string      │ int64                                               │
# ├─────────────┼─────────────────────────────────────────────────────┤
# │ VTS         │                                            73127332 │
# │ CMT         │                                            66245345 │
# └─────────────┴─────────────────────────────────────────────────────┘

# %% [markdown]
# #### database에 적재 및 운영

# %%
# in-memory database
# con = ibis.duckdb.connect()

# %%
# local database 생성 및 확인

con = ibis.duckdb.connect("mydb.duckdb")

# %ls -lh
# Out:
# total 49654400
# -rw-r--r--@ 1 hooseonlee  staff   155K Dec 18 15:35 (기술공통) DATA Engineering_커리큘럼.pdf
# -rwx------@ 1 hooseonlee  staff   199K Dec 23 09:59 00_python_training.ipynb*
# -rw-r--r--@ 1 hooseonlee  staff    41K Jan  1 16:01 01_pandas_training.ipynb
# -rw-r--r--@ 1 hooseonlee  staff   142K Jan  4 15:25 02_pandas_training.ipynb
# -rw-r--r--@ 1 hooseonlee  staff    37K Jan  7 13:29 03_numpy_training.ipynb
# -rw-r--r--@ 1 hooseonlee  staff    16K Jan  7 14:58 04_numpy_training.ipynb
# -rwx------@ 1 hooseonlee  staff   202K Jan 10 18:10 05_ibis_training.ipynb*
# -rwx------@ 1 hooseonlee  staff   498K Dec 21 19:26 06_ibis_training.ipynb*
# -rwx------@ 1 hooseonlee  staff    68K May 10  2023 08_크롤링_인터넷.ipynb*
# -rw-r--r--@ 1 hooseonlee  staff   2.5K Jan  1 15:27 100_my_pandas.py
# -rw-r--r--@ 1 hooseonlee  staff   606B Dec 29 13:40 101_my_ibis.py
# -rw-r--r--@ 1 hooseonlee  staff   1.4K Dec 29 20:35 102_my_ibis.py
# -rwx------@ 1 hooseonlee  staff   234K Jan  6  2024 99_ibis_training_3_big data.ipynb*
# -rw-r--r--@ 1 hooseonlee  staff    12K Jan 10 18:12 mydb.duckdb
# drwxr-xr-x  9 hooseonlee  staff   288B Dec 22 12:23 old/
# -rwx------@ 1 hooseonlee  staff    24G Feb 18  2025 taxi.csv*
# -rwx------@ 1 hooseonlee  staff    46M Dec 22 12:52 강의_Python.key*
# -rw-r--r--@ 1 hooseonlee  staff    15K Jan 10 17:06 연습장.ipynb

# %% [markdown]
# #### taxi 데이터 업로드

# %%
con.list_tables()
# Out:
# []

# %%
table = con.read_csv("taxi.csv")
con.create_table("taxi", table)

con.list_tables()
# Out:
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ vendor_name ┃ pickup_datetime     ┃ dropoff_datetime    ┃ passenger_count ┃ trip_distance ┃ pickup_longitude ┃ pickup_latitude ┃ rate_code     ┃ store_and_fwd ┃ dropoff_longitude ┃ dropoff_latitude ┃ payment_type ┃ fare_amount ┃ extra   ┃ mta_tax ┃ tip_amount ┃ tolls_amount ┃ total_amount ┃ improvement_surcharge ┃ month ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ string      │ timestamp(6)        │ timestamp(6)        │ int64           │ float64       │ float64          │ float64         │ string        │ boolean       │ float64           │ float64          │ string       │ float64     │ float64 │ float64 │ float64    │ float64      │ float64      │ float64               │ int64 │
# ├─────────────┼─────────────────────┼─────────────────────┼─────────────────┼───────────────┼──────────────────┼─────────────────┼───────────────┼───────────────┼───────────────────┼──────────────────┼──────────────┼─────────────┼─────────┼─────────┼────────────┼──────────────┼──────────────┼───────────────────────┼───────┤
# │ VTS         │ 2015-01-15 07:02:38 │ 2015-01-15 07:13:56 │               1 │          2.83 │       -73.944839 │       40.779278 │ Standard rate │ False         │        -73.974823 │        40.756130 │ Credit card  │        11.0 │     0.0 │     0.5 │       2.75 │          0.0 │        14.55 │                   0.3 │     1 │
# │ VTS         │ 2015-01-23 18:44:27 │ 2015-01-23 18:56:04 │               1 │          2.94 │       -73.994270 │       40.719673 │ Standard rate │ False         │        -73.971031 │        40.695774 │ Credit card  │        11.5 │     1.0 │     0.5 │       2.00 │          0.0 │        15.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:28 │ 2015-01-30 18:20:41 │               1 │          1.60 │       -73.971313 │       40.745457 │ Standard rate │ False         │        -73.991692 │        40.744473 │ Credit card  │         9.0 │     1.0 │     0.5 │       2.16 │          0.0 │        12.96 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:28 │ 2015-01-30 18:27:42 │               1 │          2.80 │       -73.989471 │       40.741554 │ Standard rate │ False         │        -73.959465 │        40.763058 │ Credit card  │        14.0 │     1.0 │     0.5 │       2.50 │          0.0 │        18.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:29 │ 2015-01-30 18:15:39 │               1 │          1.00 │       -73.973083 │       40.755447 │ Standard rate │ False         │        -73.960030 │        40.762199 │ Cash         │         6.5 │     1.0 │     0.5 │       0.00 │          0.0 │         8.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:29 │ 2015-01-30 18:14:33 │               1 │          1.00 │       -73.976807 │       40.765095 │ Standard rate │ False         │        -73.990265 │        40.771946 │ Credit card  │         5.5 │     1.0 │     0.5 │       1.45 │          0.0 │         8.75 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:29 │ 2015-01-30 18:13:36 │               1 │          0.90 │       -73.991211 │       40.733479 │ Standard rate │ True          │        -74.000237 │        40.728722 │ Credit card  │         5.5 │     1.0 │     0.5 │       2.00 │          0.0 │         9.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:30 │ 2015-01-30 18:29:36 │               1 │          3.10 │       -73.997093 │       40.737667 │ Standard rate │ False         │        -74.009613 │        40.702950 │ Credit card  │        15.0 │     1.0 │     0.5 │       3.35 │          0.0 │        20.15 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:30 │ 2015-01-30 18:36:53 │               1 │          9.00 │       -73.790398 │       40.645557 │ Standard rate │ False         │        -73.855118 │        40.729053 │ Cash         │        27.5 │     1.0 │     0.5 │       0.00 │          0.0 │        29.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:31 │ 2015-01-30 18:14:39 │               2 │          0.80 │       -73.974754 │       40.777992 │ Standard rate │ False         │        -73.981461 │        40.769997 │ Credit card  │         6.0 │     1.0 │     0.5 │       1.56 │          0.0 │         9.36 │                   0.3 │     1 │
# │ …           │ …                   │ …                   │               … │             … │                … │               … │ …             │ …             │                 … │                … │ …            │           … │       … │       … │          … │            … │            … │                     … │     … │
# └─────────────┴─────────────────────┴─────────────────────┴─────────────────┴───────────────┴──────────────────┴─────────────────┴───────────────┴───────────────┴───────────────────┴──────────────────┴──────────────┴─────────────┴─────────┴─────────┴────────────┴──────────────┴──────────────┴───────────────────────┴───────┘
# ['ibis_read_csv_hpduhgazpvhdlp5phbzwxazjxu', 'taxi']

# %%
# 특정 테이블 불러오기

df = con.table('taxi')

df
# Out:
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ vendor_name ┃ pickup_datetime     ┃ dropoff_datetime    ┃ passenger_count ┃ trip_distance ┃ pickup_longitude ┃ pickup_latitude ┃ rate_code     ┃ store_and_fwd ┃ dropoff_longitude ┃ dropoff_latitude ┃ payment_type ┃ fare_amount ┃ extra   ┃ mta_tax ┃ tip_amount ┃ tolls_amount ┃ total_amount ┃ improvement_surcharge ┃ month ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ string      │ timestamp(6)        │ timestamp(6)        │ int64           │ float64       │ float64          │ float64         │ string        │ boolean       │ float64           │ float64          │ string       │ float64     │ float64 │ float64 │ float64    │ float64      │ float64      │ float64               │ int64 │
# ├─────────────┼─────────────────────┼─────────────────────┼─────────────────┼───────────────┼──────────────────┼─────────────────┼───────────────┼───────────────┼───────────────────┼──────────────────┼──────────────┼─────────────┼─────────┼─────────┼────────────┼──────────────┼──────────────┼───────────────────────┼───────┤
# │ VTS         │ 2015-01-15 07:02:38 │ 2015-01-15 07:13:56 │               1 │          2.83 │       -73.944839 │       40.779278 │ Standard rate │ False         │        -73.974823 │        40.756130 │ Credit card  │        11.0 │     0.0 │     0.5 │       2.75 │          0.0 │        14.55 │                   0.3 │     1 │
# │ VTS         │ 2015-01-23 18:44:27 │ 2015-01-23 18:56:04 │               1 │          2.94 │       -73.994270 │       40.719673 │ Standard rate │ False         │        -73.971031 │        40.695774 │ Credit card  │        11.5 │     1.0 │     0.5 │       2.00 │          0.0 │        15.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:28 │ 2015-01-30 18:20:41 │               1 │          1.60 │       -73.971313 │       40.745457 │ Standard rate │ False         │        -73.991692 │        40.744473 │ Credit card  │         9.0 │     1.0 │     0.5 │       2.16 │          0.0 │        12.96 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:28 │ 2015-01-30 18:27:42 │               1 │          2.80 │       -73.989471 │       40.741554 │ Standard rate │ False         │        -73.959465 │        40.763058 │ Credit card  │        14.0 │     1.0 │     0.5 │       2.50 │          0.0 │        18.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:29 │ 2015-01-30 18:15:39 │               1 │          1.00 │       -73.973083 │       40.755447 │ Standard rate │ False         │        -73.960030 │        40.762199 │ Cash         │         6.5 │     1.0 │     0.5 │       0.00 │          0.0 │         8.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:29 │ 2015-01-30 18:14:33 │               1 │          1.00 │       -73.976807 │       40.765095 │ Standard rate │ False         │        -73.990265 │        40.771946 │ Credit card  │         5.5 │     1.0 │     0.5 │       1.45 │          0.0 │         8.75 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:29 │ 2015-01-30 18:13:36 │               1 │          0.90 │       -73.991211 │       40.733479 │ Standard rate │ True          │        -74.000237 │        40.728722 │ Credit card  │         5.5 │     1.0 │     0.5 │       2.00 │          0.0 │         9.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:30 │ 2015-01-30 18:29:36 │               1 │          3.10 │       -73.997093 │       40.737667 │ Standard rate │ False         │        -74.009613 │        40.702950 │ Credit card  │        15.0 │     1.0 │     0.5 │       3.35 │          0.0 │        20.15 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:30 │ 2015-01-30 18:36:53 │               1 │          9.00 │       -73.790398 │       40.645557 │ Standard rate │ False         │        -73.855118 │        40.729053 │ Cash         │        27.5 │     1.0 │     0.5 │       0.00 │          0.0 │        29.30 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:31 │ 2015-01-30 18:14:39 │               2 │          0.80 │       -73.974754 │       40.777992 │ Standard rate │ False         │        -73.981461 │        40.769997 │ Credit card  │         6.0 │     1.0 │     0.5 │       1.56 │          0.0 │         9.36 │                   0.3 │     1 │
# │ …           │ …                   │ …                   │               … │             … │                … │               … │ …             │ …             │                 … │                … │ …            │           … │       … │       … │          … │            … │            … │                     … │     … │
# └─────────────┴─────────────────────┴─────────────────────┴─────────────────┴───────────────┴──────────────────┴─────────────────┴───────────────┴───────────────┴───────────────────┴──────────────────┴──────────────┴─────────────┴─────────┴─────────┴────────────┴──────────────┴──────────────┴───────────────────────┴───────┘

# %% [markdown]
# #### 빠른 실행 확인, 파일로 실행했을 때 30초 정도 소요되었음

# %%
df.count()

taxi.group_by("vendor_name").count()
# Out:
# ┌───────────┐
# │ 139372677 │
# └───────────┘
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ vendor_name ┃ CountStar(ibis_read_csv_ar6mhd7mn5dmtbnpexnrwgw7ui) ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ string      │ int64                                               │
# ├─────────────┼─────────────────────────────────────────────────────┤
# │ CMT         │                                            66245345 │
# │ VTS         │                                            73127332 │
# └─────────────┴─────────────────────────────────────────────────────┘

# %% [markdown]
# #### Database vs. PC, 쿼리 vs. 결과

# %%
# exectue() : 전자는 쿼리 실행 (Database), 후자는 유저에게 가져옴(개인 pc)

type(df.head())
type(df.head().execute())
# Out:
# ibis.expr.types.relations.Table
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 테이블 관련 명령어 몇 개만 실행

# %%
df.columns
# Out:
# ('vendor_name',
#  'pickup_datetime',
#  'dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'pickup_longitude',
#  'pickup_latitude',
#  'rate_code',
#  'store_and_fwd',
#  'dropoff_longitude',
#  'dropoff_latitude',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'total_amount',
#  'improvement_surcharge',
#  'month')

# %%
# 원하는 명령어 계속 사용 가능

df.group_by('vendor_name').count()

df.filter(_.vendor_name == "CMT")\
  .group_by("payment_type")\
  .count()\
  .order_by(ibis.desc("CountStar()"))
# Out:
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ vendor_name ┃ CountStar(taxi) ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ string      │ int64           │
# ├─────────────┼─────────────────┤
# │ VTS         │        73127332 │
# │ CMT         │        66245345 │
# └─────────────┴─────────────────┘
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ payment_type ┃ CountStar() ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ string       │ int64       │
# ├──────────────┼─────────────┤
# │ Credit card  │    41301332 │
# │ Cash         │    24469773 │
# │ No charge    │      352051 │
# │ Dispute      │      122178 │
# │ Unknown      │          11 │
# └──────────────┴─────────────┘

# %%
# group_by 및 요약, 정렬

df.group_by(["vendor_name", "payment_type"])\
  .agg(mean_fare_amount = _.fare_amount.mean(), sum_fare_amount = _.fare_amount.sum(), count = _.vendor_name.count())\
  .order_by("vendor_name")
# Out:
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ vendor_name ┃ payment_type ┃ mean_fare_amount ┃ sum_fare_amount ┃ count    ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━┩
# │ string      │ string       │ float64          │ float64         │ int64    │
# ├─────────────┼──────────────┼──────────────────┼─────────────────┼──────────┤
# │ CMT         │ Unknown      │        10.954545 │    1.205000e+02 │       11 │
# │ CMT         │ No charge    │        10.648769 │    3.748910e+06 │   352051 │
# │ CMT         │ Credit card  │        11.601901 │    4.791740e+08 │ 41301332 │
# │ CMT         │ Dispute      │        11.763459 │    1.437236e+06 │   122178 │
# │ CMT         │ Cash         │        10.703336 │    2.619082e+08 │ 24469773 │
# │ VTS         │ Cash         │        10.807145 │    2.963122e+08 │ 27418177 │
# │ VTS         │ Credit card  │        11.675835 │    5.336925e+08 │ 45709155 │
# └─────────────┴──────────────┴──────────────────┴─────────────────┴──────────┘

# %%
# 변수 선택 관련 명령어

df.select(["vendor_name", "payment_type"])

df.select(s.contains("amount"))

df.select("vendor_name", s.numeric())

df.select(~s.matches("amount"))
# Out:
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ vendor_name ┃ payment_type ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ string      │ string       │
# ├─────────────┼──────────────┤
# │ VTS         │ Credit card  │
# │ VTS         │ Credit card  │
# │ CMT         │ Credit card  │
# │ CMT         │ Credit card  │
# │ CMT         │ Cash         │
# │ CMT         │ Credit card  │
# │ CMT         │ Credit card  │
# │ CMT         │ Credit card  │
# │ CMT         │ Cash         │
# │ CMT         │ Credit card  │
# │ …           │ …            │
# └─────────────┴──────────────┘
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ fare_amount ┃ tip_amount ┃ tolls_amount ┃ total_amount ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ float64     │ float64    │ float64      │ float64      │
# ├─────────────┼────────────┼──────────────┼──────────────┤
# │        11.0 │       2.75 │          0.0 │        14.55 │
# │        11.5 │       2.00 │          0.0 │        15.30 │
# │         9.0 │       2.16 │          0.0 │        12.96 │
# │        14.0 │       2.50 │          0.0 │        18.30 │
# │         6.5 │       0.00 │          0.0 │         8.30 │
# │         5.5 │       1.45 │          0.0 │         8.75 │
# │         5.5 │       2.00 │          0.0 │         9.30 │
# │        15.0 │       3.35 │          0.0 │        20.15 │
# │        27.5 │       0.00 │          0.0 │        29.30 │
# │         6.0 │       1.56 │          0.0 │         9.36 │
# │           … │          … │            … │            … │
# └─────────────┴────────────┴──────────────┴──────────────┘
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ vendor_name ┃ passenger_count ┃ trip_distance ┃ pickup_longitude ┃ pickup_latitude ┃ dropoff_longitude ┃ dropoff_latitude ┃ fare_amount ┃ extra   ┃ mta_tax ┃ tip_amount ┃ tolls_amount ┃ total_amount ┃ improvement_surcharge ┃ month ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ string      │ int64           │ float64       │ float64          │ float64         │ float64           │ float64          │ float64     │ float64 │ float64 │ float64    │ float64      │ float64      │ float64               │ int64 │
# ├─────────────┼─────────────────┼───────────────┼──────────────────┼─────────────────┼───────────────────┼──────────────────┼─────────────┼─────────┼─────────┼────────────┼──────────────┼──────────────┼───────────────────────┼───────┤
# │ VTS         │               1 │          2.83 │       -73.944839 │       40.779278 │        -73.974823 │        40.756130 │        11.0 │     0.0 │     0.5 │       2.75 │          0.0 │        14.55 │                   0.3 │     1 │
# │ VTS         │               1 │          2.94 │       -73.994270 │       40.719673 │        -73.971031 │        40.695774 │        11.5 │     1.0 │     0.5 │       2.00 │          0.0 │        15.30 │                   0.3 │     1 │
# │ CMT         │               1 │          1.60 │       -73.971313 │       40.745457 │        -73.991692 │        40.744473 │         9.0 │     1.0 │     0.5 │       2.16 │          0.0 │        12.96 │                   0.3 │     1 │
# │ CMT         │               1 │          2.80 │       -73.989471 │       40.741554 │        -73.959465 │        40.763058 │        14.0 │     1.0 │     0.5 │       2.50 │          0.0 │        18.30 │                   0.3 │     1 │
# │ CMT         │               1 │          1.00 │       -73.973083 │       40.755447 │        -73.960030 │        40.762199 │         6.5 │     1.0 │     0.5 │       0.00 │          0.0 │         8.30 │                   0.3 │     1 │
# │ CMT         │               1 │          1.00 │       -73.976807 │       40.765095 │        -73.990265 │        40.771946 │         5.5 │     1.0 │     0.5 │       1.45 │          0.0 │         8.75 │                   0.3 │     1 │
# │ CMT         │               1 │          0.90 │       -73.991211 │       40.733479 │        -74.000237 │        40.728722 │         5.5 │     1.0 │     0.5 │       2.00 │          0.0 │         9.30 │                   0.3 │     1 │
# │ CMT         │               1 │          3.10 │       -73.997093 │       40.737667 │        -74.009613 │        40.702950 │        15.0 │     1.0 │     0.5 │       3.35 │          0.0 │        20.15 │                   0.3 │     1 │
# │ CMT         │               1 │          9.00 │       -73.790398 │       40.645557 │        -73.855118 │        40.729053 │        27.5 │     1.0 │     0.5 │       0.00 │          0.0 │        29.30 │                   0.3 │     1 │
# │ CMT         │               2 │          0.80 │       -73.974754 │       40.777992 │        -73.981461 │        40.769997 │         6.0 │     1.0 │     0.5 │       1.56 │          0.0 │         9.36 │                   0.3 │     1 │
# │ …           │               … │             … │                … │               … │                 … │                … │           … │       … │       … │          … │            … │            … │                     … │     … │
# └─────────────┴─────────────────┴───────────────┴──────────────────┴─────────────────┴───────────────────┴──────────────────┴─────────────┴─────────┴─────────┴────────────┴──────────────┴──────────────┴───────────────────────┴───────┘
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ vendor_name ┃ pickup_datetime     ┃ dropoff_datetime    ┃ passenger_count ┃ trip_distance ┃ pickup_longitude ┃ pickup_latitude ┃ rate_code     ┃ store_and_fwd ┃ dropoff_longitude ┃ dropoff_latitude ┃ payment_type ┃ extra   ┃ mta_tax ┃ improvement_surcharge ┃ month ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ string      │ timestamp(6)        │ timestamp(6)        │ int64           │ float64       │ float64          │ float64         │ string        │ boolean       │ float64           │ float64          │ string       │ float64 │ float64 │ float64               │ int64 │
# ├─────────────┼─────────────────────┼─────────────────────┼─────────────────┼───────────────┼──────────────────┼─────────────────┼───────────────┼───────────────┼───────────────────┼──────────────────┼──────────────┼─────────┼─────────┼───────────────────────┼───────┤
# │ VTS         │ 2015-01-15 07:02:38 │ 2015-01-15 07:13:56 │               1 │          2.83 │       -73.944839 │       40.779278 │ Standard rate │ False         │        -73.974823 │        40.756130 │ Credit card  │     0.0 │     0.5 │                   0.3 │     1 │
# │ VTS         │ 2015-01-23 18:44:27 │ 2015-01-23 18:56:04 │               1 │          2.94 │       -73.994270 │       40.719673 │ Standard rate │ False         │        -73.971031 │        40.695774 │ Credit card  │     1.0 │     0.5 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:28 │ 2015-01-30 18:20:41 │               1 │          1.60 │       -73.971313 │       40.745457 │ Standard rate │ False         │        -73.991692 │        40.744473 │ Credit card  │     1.0 │     0.5 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:28 │ 2015-01-30 18:27:42 │               1 │          2.80 │       -73.989471 │       40.741554 │ Standard rate │ False         │        -73.959465 │        40.763058 │ Credit card  │     1.0 │     0.5 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:29 │ 2015-01-30 18:15:39 │               1 │          1.00 │       -73.973083 │       40.755447 │ Standard rate │ False         │        -73.960030 │        40.762199 │ Cash         │     1.0 │     0.5 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:29 │ 2015-01-30 18:14:33 │               1 │          1.00 │       -73.976807 │       40.765095 │ Standard rate │ False         │        -73.990265 │        40.771946 │ Credit card  │     1.0 │     0.5 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:29 │ 2015-01-30 18:13:36 │               1 │          0.90 │       -73.991211 │       40.733479 │ Standard rate │ True          │        -74.000237 │        40.728722 │ Credit card  │     1.0 │     0.5 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:30 │ 2015-01-30 18:29:36 │               1 │          3.10 │       -73.997093 │       40.737667 │ Standard rate │ False         │        -74.009613 │        40.702950 │ Credit card  │     1.0 │     0.5 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:30 │ 2015-01-30 18:36:53 │               1 │          9.00 │       -73.790398 │       40.645557 │ Standard rate │ False         │        -73.855118 │        40.729053 │ Cash         │     1.0 │     0.5 │                   0.3 │     1 │
# │ CMT         │ 2015-01-30 18:08:31 │ 2015-01-30 18:14:39 │               2 │          0.80 │       -73.974754 │       40.777992 │ Standard rate │ False         │        -73.981461 │        40.769997 │ Credit card  │     1.0 │     0.5 │                   0.3 │     1 │
# │ …           │ …                   │ …                   │               … │             … │                … │               … │ …             │ …             │                 … │                … │ …            │       … │       … │                     … │     … │
# └─────────────┴─────────────────────┴─────────────────────┴─────────────────┴───────────────┴──────────────────┴─────────────────┴───────────────┴───────────────┴───────────────────┴──────────────────┴──────────────┴─────────┴─────────┴───────────────────────┴───────┘

# %%
# 변수 생성 및 rename

df.mutate(km = _.trip_distance * 1.6)\
  .select("trip_distance", "km")

df.trip_distance.mean()
df["trip_distance"].mean()

df.agg([df.trip_distance.mean(), df.trip_distance.min(), df.trip_distance.max().name("max_distance")])
df[["vendor_name", "payment_type"]].distinct()
# Out:
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ trip_distance ┃ km      ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ float64       │ float64 │
# ├───────────────┼─────────┤
# │          2.83 │   4.528 │
# │          2.94 │   4.704 │
# │          1.60 │   2.560 │
# │          2.80 │   4.480 │
# │          1.00 │   1.600 │
# │          1.00 │   1.600 │
# │          0.90 │   1.440 │
# │          3.10 │   4.960 │
# │          9.00 │  14.400 │
# │          0.80 │   1.280 │
# │             … │       … │
# └───────────────┴─────────┘
# ┌──────────┐
# │ 2.448804 │
# └──────────┘
# ┌──────────┐
# │ 2.448804 │
# └──────────┘
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Mean(trip_distance) ┃ Min(trip_distance) ┃ max_distance ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ float64             │ float64            │ float64      │
# ├─────────────────────┼────────────────────┼──────────────┤
# │            2.448804 │               0.01 │        14.99 │
# └─────────────────────┴────────────────────┴──────────────┘
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ vendor_name ┃ payment_type ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ string      │ string       │
# ├─────────────┼──────────────┤
# │ CMT         │ No charge    │
# │ CMT         │ Dispute      │
# │ VTS         │ Credit card  │
# │ CMT         │ Cash         │
# │ CMT         │ Unknown      │
# │ VTS         │ Cash         │
# │ CMT         │ Credit card  │
# └─────────────┴──────────────┘

# %% [markdown]
# #### sql 문법과 비교

# %%
df_filtered = df.filter(_.vendor_name == "VST")\
                .agg([_.fare_amount.sum(), _.fare_amount.mean()])

ibis.to_sql(df_filtered)
# Out:
# SELECT
#   SUM("t1"."fare_amount") AS "Sum(fare_amount)",
#   AVG("t1"."fare_amount") AS "Mean(fare_amount)"
# FROM (
#   SELECT
#     *
#   FROM "taxi" AS "t0"
#   WHERE
#     "t0"."vendor_name" = 'VST'
# ) AS "t1"

# %% [markdown]
# #### 파일로 내보내기

# %%
type(df_filtered)

con.to_csv(df_filtered, path = "tmp.csv")

os.listdir(".")
glob.glob('*.csv')
# Out:
# ibis.expr.types.relations.Table
# ['.Rhistory',
#  '(기술공통) DATA Engineering_커리큘럼.pdf',
#  '연습장.ipynb',
#  '.DS_Store',
#  '04_numpy_training.ipynb',
#  '101_my_ibis.py',
#  '02_pandas_training.ipynb',
#  'old',
#  '99_ibis_training_3_big data.ipynb',
#  '08_크롤링_인터넷.ipynb',
#  'mydb.duckdb',
#  'tmp.csv',
#  '03_numpy_training.ipynb',
#  '102_my_ibis.py',
#  '06_ibis_training.ipynb',
#  '05_ibis_training.ipynb',
#  '.Rapp.history',
#  'taxi.csv',
#  '강의_Python.key',
#  '01_pandas_training.ipynb',
#  '00_python_training.ipynb',
#  '100_my_pandas.py']
# ['tmp.csv', 'taxi.csv']

# %% [markdown]
# #### 원격 데이터 베이스 연결

# %%
# 원격 PostgreSQL 서버 연결
# conn = ibis.postgres.connect(
#     host = 'your-server.com',        # 또는 IP 주소 (예: '192.168.1.100')
#     port = 5432,                     # 서버 관리자 제공 (기본은 5432)
#     user = 'postgres',               # 서버 관리자 제공
#     password = '1234',               # 서버 관리자 제공
#     database = 'postgres'            # 접속할 데이터 베이스 이름
# )

# 데이터베이스 및 테이블 확인
# dbs = conn.list_databases()
# print(dbs)

# tables = conn.list_tables()
# print(tables)
