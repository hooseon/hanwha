# %%
# 필요한 라이브러리 import
import warnings
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from IPython.core.interactiveshell import InteractiveShell

# 경고 메시지 무시
warnings.filterwarnings('ignore')

# 모든 출력 표시
InteractiveShell.ast_node_interactivity = "all"

# 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# 한글 폰트 설정 (Mac)
mpl.rcParams['font.family'] = "AppleGothic" # 윈도우는 'Malgun Gothic' 사용

# %%
mpg = sns.load_dataset("mpg")
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
mpg[mpg.isna().any(axis=1)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
mpg["horsepower"] = mpg.groupby("cylinders")["horsepower"].transform(
    lambda x: x.fillna(x.median())
)

mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ### 변수 유형 변환 : 변수 유형은 왜 고민해야 할까요?

# %%
mpg["origin"] = mpg["origin"].astype("category")
mpg["name"]   = mpg["name"].astype("category")

mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    category
#  8   name          398 non-null    category
# dtypes: category(2), float64(4), int64(3)
# memory usage: 33.7 KB

# %% [markdown]
# ### 범주형 데이터 범주 보기

# %%
mpg["origin"].value_counts()
mpg["name"].value_counts(normalize=True)
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64
# name
# ford pinto              0.015075
# ford maverick           0.012563
# amc matador             0.012563
# toyota corolla          0.012563
# chevrolet impala        0.010050
#                           ...
# dodge st. regis         0.002513
# fiat 124 sport coupe    0.002513
# fiat 124 tc             0.002513
# fiat 124b               0.002513
# vw rabbit custom        0.002513
# Name: proportion, Length: 305, dtype: float64

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# #### 행추출

# %%
# 4기통만 추출
mpg[mpg["cylinders"] == 4]

# 4기통과 6기통 추출
mpg[(mpg["cylinders"] == 4) | (mpg["cylinders"] == 6)]

# isin 함수 사용
mpg[mpg["cylinders"].isin([4, 6])]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                          name
# 14           70   japan         toyota corona mark ii
# 18           70   japan                  datsun pl510
# 19           70  europe  volkswagen 1131 deluxe sedan
# 20           70  europe                   peugeot 504
# 21           70  europe                   audi 100 ls
# ..          ...     ...                           ...
# 393          82     usa               ford mustang gl
# 394          82  europe                     vw pickup
# 395          82     usa                 dodge rampage
# 396          82     usa                   ford ranger
# 397          82     usa                    chevy s-10
#
# [204 rows x 9 columns]
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 15   22.0          6         198.0        95.0    2833          15.5
# 16   18.0          6         199.0        97.0    2774          15.5
# 17   21.0          6         200.0        85.0    2587          16.0
# 18   27.0          4          97.0        88.0    2130          14.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                   name
# 14           70   japan  toyota corona mark ii
# 15           70     usa        plymouth duster
# 16           70     usa             amc hornet
# 17           70     usa          ford maverick
# 18           70   japan           datsun pl510
# ..          ...     ...                    ...
# 393          82     usa        ford mustang gl
# 394          82  europe              vw pickup
# 395          82     usa          dodge rampage
# 396          82     usa            ford ranger
# 397          82     usa             chevy s-10
#
# [288 rows x 9 columns]
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 15   22.0          6         198.0        95.0    2833          15.5
# 16   18.0          6         199.0        97.0    2774          15.5
# 17   21.0          6         200.0        85.0    2587          16.0
# 18   27.0          4          97.0        88.0    2130          14.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                   name
# 14           70   japan  toyota corona mark ii
# 15           70     usa        plymouth duster
# 16           70     usa             amc hornet
# 17           70     usa          ford maverick
# 18           70   japan           datsun pl510
# ..          ...     ...                    ...
# 393          82     usa        ford mustang gl
# 394          82  europe              vw pickup
# 395          82     usa          dodge rampage
# 396          82     usa            ford ranger
# 397          82     usa             chevy s-10
#
# [288 rows x 9 columns]

# %%
# 연비 평균보다 높은 행 추출
mpg["mpg"].mean()
mpg[mpg["mpg"] > mpg["mpg"].mean()]

# 그룹별 연비 평균보다 높은 행 추출
mpg.groupby("cylinders")["mpg"].mean()
mpg[mpg["mpg"] > mpg.groupby("cylinders")["mpg"].transform("mean")]
# Out:
# np.float64(23.514572864321607)
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                          name
# 14           70   japan         toyota corona mark ii
# 18           70   japan                  datsun pl510
# 19           70  europe  volkswagen 1131 deluxe sedan
# 20           70  europe                   peugeot 504
# 21           70  europe                   audi 100 ls
# ..          ...     ...                           ...
# 393          82     usa               ford mustang gl
# 394          82  europe                     vw pickup
# 395          82     usa                 dodge rampage
# 396          82     usa                   ford ranger
# 397          82     usa                    chevy s-10
#
# [189 rows x 9 columns]
# cylinders
# 3    20.550000
# 4    29.286765
# 5    27.366667
# 6    19.985714
# 8    14.963107
# Name: mpg, dtype: float64
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 390          82   japan           toyota celica gt
# 391          82     usa          dodge charger 2.2
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 397          82     usa                 chevy s-10
#
# [183 rows x 9 columns]

# %% [markdown]
# ### groupby 예제

# %%
# 특정 컬럼만
mpg.groupby("cylinders")["mpg"].mean()

# 여러 컬럼
mpg.groupby("cylinders")[["mpg", "horsepower"]].mean()

# 여러 통계량
mpg.groupby("cylinders")["mpg"].agg(["mean", "median", "std"])
# Out:
# cylinders
# 3    20.550000
# 4    29.286765
# 5    27.366667
# 6    19.985714
# 8    14.963107
# Name: mpg, dtype: float64
#                  mpg  horsepower
# cylinders
# 3          20.550000   99.250000
# 4          29.286765   78.274510
# 5          27.366667   82.333333
# 6          19.985714  101.488095
# 8          14.963107  158.300971
#                 mean  median       std
# cylinders
# 3          20.550000   20.25  2.564501
# 4          29.286765   28.25  5.710156
# 5          27.366667   25.40  8.228204
# 6          19.985714   19.00  3.807322
# 8          14.963107   14.00  2.836284

# %% [markdown]
# ### 열추출

# %%
# 변수명 사용
mpg[["mpg", "cylinders"]]

# 수치형 변수만 선택
mpg.select_dtypes(include = 'number')
mpg.select_dtypes(include = 'int64')

# 정규 표현식 사용
mpg.filter(regex = "^o")    # "o"로 시작하는 변수
mpg.filter(regex = "t$")    # "t"로 끝나는 변수
mpg.filter(regex = "_")     # "_"가 포함된 변수
# Out:
#       mpg  cylinders
# 0    18.0          8
# 1    15.0          8
# 2    18.0          8
# 3    16.0          8
# 4    17.0          8
# ..    ...        ...
# 393  27.0          4
# 394  44.0          4
# 395  32.0          4
# 396  28.0          4
# 397  31.0          4
#
# [398 rows x 2 columns]
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# 393          82
# 394          82
# 395          82
# 396          82
# 397          82
#
# [398 rows x 7 columns]
#      cylinders  weight  model_year
# 0            8    3504          70
# 1            8    3693          70
# 2            8    3436          70
# 3            8    3433          70
# 4            8    3449          70
# ..         ...     ...         ...
# 393          4    2790          82
# 394          4    2130          82
# 395          4    2295          82
# 396          4    2625          82
# 397          4    2720          82
#
# [398 rows x 3 columns]
#      origin
# 0       usa
# 1       usa
# 2       usa
# 3       usa
# 4       usa
# ..      ...
# 393     usa
# 394  europe
# 395     usa
# 396     usa
# 397     usa
#
# [398 rows x 1 columns]
#      displacement  weight
# 0           307.0    3504
# 1           350.0    3693
# 2           318.0    3436
# 3           304.0    3433
# 4           302.0    3449
# ..            ...     ...
# 393         140.0    2790
# 394          97.0    2130
# 395         135.0    2295
# 396         120.0    2625
# 397         119.0    2720
#
# [398 rows x 2 columns]
#      model_year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# 393          82
# 394          82
# 395          82
# 396          82
# 397          82
#
# [398 rows x 1 columns]

# %% [markdown]
# ### 정렬

# %%
mpg.sort_values("cylinders", ascending = False)
mpg.sort_values(["cylinders", "mpg"], ascending = [True, False])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 86   14.0          8         304.0       150.0    3672          11.5
# 230  15.5          8         350.0       170.0    4165          11.4
# 231  15.5          8         400.0       190.0    4325          12.2
# 232  16.0          8         351.0       149.0    4335          14.5
# ..    ...        ...           ...         ...     ...           ...
# 81   28.0          4          97.0        92.0    2288          17.0
# 243  21.5          3          80.0       110.0    2720          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 111  18.0          3          70.0        90.0    2124          13.5
#
#      model_year origin                          name
# 0            70    usa     chevrolet chevelle malibu
# 86           73    usa                   amc matador
# 230          77    usa  chevrolet monte carlo landau
# 231          77    usa              chrysler cordoba
# 232          77    usa              ford thunderbird
# ..          ...    ...                           ...
# 81           72  japan               datsun 510 (sw)
# 243          77  japan                    mazda rx-4
# 334          80  japan                 mazda rx-7 gs
# 71           72  japan               mazda rx2 coupe
# 111          73  japan                     maxda rx3
#
# [398 rows x 9 columns]
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 334  23.7          3          70.0       100.0    2420          12.5
# 243  21.5          3          80.0       110.0    2720          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 111  18.0          3          70.0        90.0    2124          13.5
# 322  46.6          4          86.0        65.0    2110          17.9
# ..    ...        ...           ...         ...     ...           ...
# 103  11.0          8         400.0       150.0    4997          14.0
# 124  11.0          8         350.0       180.0    3664          11.0
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 28    9.0          8         304.0       193.0    4732          18.5
#
#      model_year origin              name
# 334          80  japan     mazda rx-7 gs
# 243          77  japan        mazda rx-4
# 71           72  japan   mazda rx2 coupe
# 111          73  japan         maxda rx3
# 322          80  japan         mazda glc
# ..          ...    ...               ...
# 103          73    usa  chevrolet impala
# 124          73    usa  oldsmobile omega
# 25           70    usa         ford f250
# 26           70    usa         chevy c20
# 28           70    usa          hi 1200d
#
# [398 rows x 9 columns]

# %% [markdown]
# ### 변수 생성

# %%
mpg["kml"] = (mpg["mpg"] * 0.425).round(2)
mpg

mpg.sort_values(["cylinders", "kml"], ascending=[True, False])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name    kml
# 0            70     usa  chevrolet chevelle malibu   7.65
# 1            70     usa          buick skylark 320   6.38
# 2            70     usa         plymouth satellite   7.65
# 3            70     usa              amc rebel sst   6.80
# 4            70     usa                ford torino   7.22
# ..          ...     ...                        ...    ...
# 393          82     usa            ford mustang gl  11.48
# 394          82  europe                  vw pickup  18.70
# 395          82     usa              dodge rampage  13.60
# 396          82     usa                ford ranger  11.90
# 397          82     usa                 chevy s-10  13.18
#
# [398 rows x 10 columns]
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 334  23.7          3          70.0       100.0    2420          12.5
# 243  21.5          3          80.0       110.0    2720          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 111  18.0          3          70.0        90.0    2124          13.5
# 322  46.6          4          86.0        65.0    2110          17.9
# ..    ...        ...           ...         ...     ...           ...
# 103  11.0          8         400.0       150.0    4997          14.0
# 124  11.0          8         350.0       180.0    3664          11.0
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 28    9.0          8         304.0       193.0    4732          18.5
#
#      model_year origin              name    kml
# 334          80  japan     mazda rx-7 gs  10.07
# 243          77  japan        mazda rx-4   9.14
# 71           72  japan   mazda rx2 coupe   8.07
# 111          73  japan         maxda rx3   7.65
# 322          80  japan         mazda glc  19.80
# ..          ...    ...               ...    ...
# 103          73    usa  chevrolet impala   4.68
# 124          73    usa  oldsmobile omega   4.68
# 25           70    usa         ford f250   4.25
# 26           70    usa         chevy c20   4.25
# 28           70    usa          hi 1200d   3.82
#
# [398 rows x 10 columns]

# %% [markdown]
# ### 그룹별 요약

# %%
# 단변수 요약
mpg.groupby("cylinders")["kml"].mean().reset_index()

# 2개 변수 선택 요약
mpg.groupby(["cylinders", "origin"])["kml"].mean().reset_index()

# 수치형 데이터 모두 요약
num_var = mpg.select_dtypes(include = "number")
num_var.groupby('cylinders').mean()

# 여러 통계량 한번에
mpg.groupby('cylinders')['mpg'].agg(['count', 'mean', 'median', 'min', 'max', 'std'])
# Out:
#    cylinders        kml
# 0          3   8.732500
# 1          4  12.446716
# 2          5  11.633333
# 3          6   8.492976
# 4          8   6.358932
#     cylinders  origin        kml
# 0           3  europe        NaN
# 1           3   japan   8.732500
# 2           3     usa        NaN
# 3           4  europe  12.074127
# 4           4   japan  13.428116
# 5           4     usa  11.832222
# 6           5  europe  11.633333
# 7           5   japan        NaN
# 8           5     usa        NaN
# 9           6  europe   8.540000
# 10          6   japan  10.150000
# 11          6     usa   8.356081
# 12          8  europe        NaN
# 13          8   japan        NaN
# 14          8     usa   6.358932
#                  mpg  displacement  horsepower       weight  acceleration  \
# cylinders
# 3          20.550000     72.500000   99.250000  2398.500000     13.250000
# 4          29.286765    109.796569   78.274510  2308.127451     16.601471
# 5          27.366667    145.000000   82.333333  3103.333333     18.633333
# 6          19.985714    218.142857  101.488095  3198.226190     16.263095
# 8          14.963107    345.009709  158.300971  4114.718447     12.955340
#
#            model_year        kml
# cylinders
# 3           75.500000   8.732500
# 4           77.073529  12.446716
# 5           79.000000  11.633333
# 6           75.928571   8.492976
# 8           73.902913   6.358932
#            count       mean  median   min   max       std
# cylinders
# 3              4  20.550000   20.25  18.0  23.7  2.564501
# 4            204  29.286765   28.25  18.0  46.6  5.710156
# 5              3  27.366667   25.40  20.3  36.4  8.228204
# 6             84  19.985714   19.00  15.0  38.0  3.807322
# 8            103  14.963107   14.00   9.0  26.6  2.836284

# %%
# 사용자 정의 함수
mpg.groupby('cylinders')['mpg'].agg(['mean', ('range', lambda x: x.max() - x.min())])

# 백분위수
mpg.groupby('cylinders')['mpg'].agg(['mean', ('Q1', lambda x: x.quantile(0.25)), ('Q3', lambda x: x.quantile(0.75))])
# Out:
#                 mean  range
# cylinders
# 3          20.550000    5.7
# 4          29.286765   28.6
# 5          27.366667   16.1
# 6          19.985714   23.0
# 8          14.963107   17.6
#                 mean     Q1     Q3
# cylinders
# 3          20.550000  18.75  22.05
# 4          29.286765  25.00  33.00
# 5          27.366667  22.85  30.90
# 6          19.985714  18.00  21.00
# 8          14.963107  13.00  16.00

# %% [markdown]
# ### 정규화는 지금 해도 되지만 피처 엔지니어링할 때 해도 됩니다.

# %%
# 그룹별 정규화 (z-score)
mpg['mpg_zscore'] = mpg.groupby('cylinders')['mpg'].transform(lambda x: (x - x.mean()) / x.std())
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name    kml  mpg_zscore
# 0            70     usa  chevrolet chevelle malibu   7.65    1.070730
# 1            70     usa          buick skylark 320   6.38    0.013008
# 2            70     usa         plymouth satellite   7.65    1.070730
# 3            70     usa              amc rebel sst   6.80    0.365582
# 4            70     usa                ford torino   7.22    0.718156
# ..          ...     ...                        ...    ...         ...
# 393          82     usa            ford mustang gl  11.48   -0.400473
# 394          82  europe                  vw pickup  18.70    2.576678
# 395          82     usa              dodge rampage  13.60    0.475160
# 396          82     usa                ford ranger  11.90   -0.225347
# 397          82     usa                 chevy s-10  13.18    0.300033
#
# [398 rows x 11 columns]

# %% [markdown]
# #### join, concat

# %%
# join tables
a = {
  "이름" : ["철수", "영희"],
  "나이" : [3, 5] }

b = pd.DataFrame.from_dict(a)

a
b
# Out:
# {'이름': ['철수', '영희'], '나이': [3, 5]}
#    이름  나이
# 0  철수   3
# 1  영희   5

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
c = pd.DataFrame({
  "이름" : ["철수", "길동"],
  "주소" : ["분당", "일산"]})
c
# Out:
#    이름  주소
# 0  철수  분당
# 1  길동  일산

# %%
  
pd.merge(b, c, how = "left", on = "이름")
# Out:
#    이름  나이   주소
# 0  철수   3   분당
# 1  영희   5  NaN

# %%
pd.merge(b, c, how = "right")
# Out:
#    이름   나이  주소
# 0  철수  3.0  분당
# 1  길동  NaN  일산

# %%
pd.merge(b, c, how = "outer")
# Out:
#    이름   나이   주소
# 0  길동  NaN   일산
# 1  영희  5.0  NaN
# 2  철수  3.0   분당

# %%
# concatenate
pd.concat([b, c], axis = 1)
# Out:
#    이름  나이  이름  주소
# 0  철수   3  철수  분당
# 1  영희   5  길동  일산
